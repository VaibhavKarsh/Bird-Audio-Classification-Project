# %%
import requests
import os
import pandas as pd
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
def download_file(file_url, file_path):
    """Downloads a single file and saves it to the specified path."""
    try:
        with requests.get(file_url, stream=True) as r:
            r.raise_for_status()
            with open(file_path, 'wb') as f:
                for chunk in r.iter_content(chunk_size=8192):
                    f.write(chunk)
        print(f"Downloaded: {file_path}")
    except Exception as e:
        print(f"Error downloading {file_path}: {e}")

def download_audio_files(data, folder_name):
    """Downloads audio files based on the data and saves them to the specified folder."""
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    
    with ThreadPoolExecutor(max_workers=5) as executor:  # Adjust the number of workers as needed
        future_to_file = {}
        for record in data['recordings'][:200]:
            file_url = record['file']
            file_name = f"{record['id']}.mp3"
            file_path = os.path.join(folder_name, file_name)
            future = executor.submit(download_file, file_url, file_path)
            future_to_file[future] = file_path
        
        # Wait for all futures to complete
        for future in as_completed(future_to_file):
            future_to_file[future]

# %%
i="1"

# %%
def download_metadata(data, folder_name, common_name):
    """Collects metadata for each recording and saves it to a CSV."""
    global i  # Declare i as global to modify its value outside the function
    metadata = []

    for record in data['recordings'][:200]:
        file_name = f"{record['id']}.mp3"  # Keep the file name, not the full path

        # Collect metadata for each recording with the specified columns
        metadata.append({
            "filename": file_name,
            "country": record.get('cnt'),
            "name": common_name,
            "lat": record.get('lat'),   # Latitude
            "lng": record.get('lng'),
            "fold": i
        })

    # Save metadata to CSV inside the species folder
    metadata_df = pd.DataFrame(metadata)
    metadata_df.to_csv(os.path.join(folder_name, "metadata.csv"), index=False)
    i = str(int(i) + 1)
    print(f"Metadata saved to {folder_name}/metadata.csv")

# %%
species = "Common Pheasant"
records = 200
url = f"https://www.xeno-canto.org/api/2/recordings?query={species}&num={records}"
response = requests.get(url)
data = response.json()

# %%
common_name = data['recordings'][0]['en']
folder_name = "sample"

# %%
download_audio_files(data, folder_name+i)
# Out:
# Downloaded: sample10\916392.mp3
# Downloaded: sample10\916393.mp3
# Downloaded: sample10\922701.mp3
# Downloaded: sample10\895082.mp3
# Downloaded: sample10\890518.mp3
# Downloaded: sample10\871904.mp3
# Downloaded: sample10\881961.mp3
# Downloaded: sample10\840640.mp3
# Downloaded: sample10\872784.mp3
# Downloaded: sample10\835192.mp3
# Downloaded: sample10\808441.mp3
# Downloaded: sample10\799489.mp3
# Downloaded: sample10\801092.mp3
# Downloaded: sample10\796121.mp3
# Downloaded: sample10\884861.mp3
# Downloaded: sample10\792476.mp3
# Downloaded: sample10\929867.mp3
# Downloaded: sample10\792839.mp3
# Downloaded: sample10\792475.mp3
# Downloaded: sample10\791216.mp3
# Downloaded: sample10\786448.mp3
# Downloaded: sample10\776246.mp3
# Downloaded: sample10\766428.mp3
# Downloaded: sample10\784775.mp3
# Downloaded: sample10\784065.mp3
# Downloaded: sample10\749402.mp3
# Downloaded: sample10\738441.mp3
# Downloaded: sample10\738400.mp3
# Downloaded: sample10\738398.mp3
# Downloaded: sample10\738324.mp3
# Downloaded: sample10\738315.mp3
# Downloaded: sample10\738312.mp3
# Downloaded: sample10\738306.mp3
# Downloaded: sample10\732129.mp3
# Downloaded: sample10\406063.mp3
# Downloaded: sample10\383120.mp3
# Downloaded: sample10\464102.mp3
# Downloaded: sample10\376895.mp3
# Downloaded: sample10\364762.mp3
# Downloaded: sample10\364959.mp3
# Downloaded: sample10\364387.mp3
# Downloaded: sample10\441882.mp3
# Downloaded: sample10\376894.mp3
# Downloaded: sample10\357232.mp3
# Downloaded: sample10\332561.mp3
# Downloaded: sample10\364710.mp3
# Downloaded: sample10\342048.mp3
# Downloaded: sample10\340686.mp3
# Downloaded: sample10\343433.mp3
# Downloaded: sample10\327185.mp3
# Downloaded: sample10\327186.mp3
# Downloaded: sample10\295960.mp3
# Downloaded: sample10\303558.mp3
# Downloaded: sample10\302765.mp3
# Downloaded: sample10\281835.mp3
# Downloaded: sample10\281838.mp3
# Downloaded: sample10\287893.mp3
# Downloaded: sample10\281834.mp3
# Downloaded: sample10\235445.mp3
# Downloaded: sample10\254700.mp3
# Downloaded: sample10\266712.mp3
# Downloaded: sample10\234112.mp3
# Downloaded: sample10\266713.mp3
# Downloaded: sample10\183798.mp3
# Downloaded: sample10\213919.mp3
# Downloaded: sample10\174770.mp3
# Downloaded: sample10\173885.mp3
# Downloaded: sample10\170681.mp3
# Downloaded: sample10\163168.mp3
# Downloaded: sample10\287890.mp3
# Downloaded: sample10\156436.mp3
# Downloaded: sample10\179662.mp3
# Downloaded: sample10\153129.mp3
# Downloaded: sample10\153127.mp3
# Downloaded: sample10\150572.mp3
# Downloaded: sample10\150571.mp3
# Downloaded: sample10\153126.mp3
# Downloaded: sample10\130265.mp3
# Downloaded: sample10\155697.mp3
# Downloaded: sample10\120359.mp3
# Downloaded: sample10\149146.mp3
# Downloaded: sample10\121325.mp3
# Downloaded: sample10\93150.mp3
# Downloaded: sample10\76852.mp3
# Downloaded: sample10\92053.mp3
# Downloaded: sample10\76851.mp3
# Downloaded: sample10\104186.mp3
# Downloaded: sample10\75988.mp3
# Downloaded: sample10\75856.mp3
# Downloaded: sample10\46412.mp3
# Downloaded: sample10\46283.mp3
# Downloaded: sample10\121326.mp3
# Downloaded: sample10\57511.mp3
# Downloaded: sample10\29209.mp3
# Downloaded: sample10\22694.mp3
# Downloaded: sample10\27994.mp3
# Downloaded: sample10\21206.mp3
# Downloaded: sample10\916391.mp3
# Downloaded: sample10\929868.mp3
# Downloaded: sample10\913907.mp3
# Downloaded: sample10\909613.mp3
# Downloaded: sample10\909612.mp3
# Downloaded: sample10\909611.mp3
# Downloaded: sample10\909609.mp3
# Downloaded: sample10\906968.mp3
# Downloaded: sample10\895138.mp3
# Downloaded: sample10\906840.mp3
# Downloaded: sample10\895055.mp3
# Downloaded: sample10\895031.mp3
# Downloaded: sample10\892805.mp3
# Downloaded: sample10\890873.mp3
# Downloaded: sample10\892804.mp3
# Downloaded: sample10\894646.mp3
# Downloaded: sample10\903723.mp3
# Downloaded: sample10\884863.mp3
# Downloaded: sample10\884862.mp3

# %%
download_metadata(data, folder_name+i, common_name)
# Out:
# Metadata saved to sample10/metadata.csv
